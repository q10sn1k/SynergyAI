# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\data\innopolis\innopolis_labs\lr9\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\data\innopolis\innopolis_labs\lr9\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\data\innopolis\innopolis_labs\lr9\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## Примените метод k-means для данных diabetes.csv
# ## Постройте кластера для следующих комбинаций атрибутов
# ## -показатель BMI, возраст Age
# ## -показатель BloodPressure, возрастAge
# ## Визуализируйте результат

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt


df = pd.read_csv('diabetes.csv')

df = df.dropna()

df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0             6      148             72             35        0  33.6  \
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
# k-means для BMI, Age
X1 = df[['BMI', 'Age']].values
kmeans1 = KMeans(n_clusters=2, n_init=10, random_state=0).fit(X1)

plt.figure(figsize=(8, 6))
plt.scatter(X1[:, 0], X1[:, 1], c=kmeans1.labels_)
plt.scatter(kmeans1.cluster_centers_[:, 0], kmeans1.cluster_centers_[:, 1], s=300, c='red')
plt.xlabel('BMI')
plt.ylabel('Age')
plt.title('Кластеры для BMI and Age')
plt.show()

# k-means для BloodPressure, Age
X2 = df[['BloodPressure', 'Age']].values
kmeans2 = KMeans(n_clusters=2, n_init=10, random_state=0).fit(X2)

plt.figure(figsize=(8, 6))
plt.scatter(X2[:, 0], X2[:, 1], c=kmeans2.labels_)
plt.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 1], s=300, c='red')
plt.xlabel('BloodPressure')
plt.ylabel('Age')
plt.title('Кластеры для BloodPressure and Age')
plt.show()

# %% [markdown]
# ## Применитеметодиерархическойкластеризациисвыводомдендрограммыдлятехжекомбинацийатрибутов

# %% [markdown]
# ## single

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Для "BMI, Age"
linked1 = linkage(df[['BMI', 'Age']], 'single')

plt.figure(figsize=(10, 7))
dendrogram(linked1,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BMI and Age')
plt.show()

# Для "BloodPressure, Age"
linked2 = linkage(df[['BloodPressure', 'Age']], 'single')

plt.figure(figsize=(10, 7))
dendrogram(linked2,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BloodPressure и Age')
plt.show()

# %% [markdown]
# ## complete

# %%
# Для "BMI, Age"
linked1 = linkage(df[['BMI', 'Age']], 'complete')

plt.figure(figsize=(10, 7))
dendrogram(linked1,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BMI и Age')
plt.show()

# Для "BloodPressure, Age"
linked2 = linkage(df[['BloodPressure', 'Age']], 'complete')

plt.figure(figsize=(10, 7))
dendrogram(linked2,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BloodPressure и Age')
plt.show()

# %% [markdown]
# ## average

# %%
# Для "BMI, Age"
linked1 = linkage(df[['BMI', 'Age']], 'average')

plt.figure(figsize=(10, 7))
dendrogram(linked1,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BMI и Age')
plt.show()

# Для "BloodPressure, Age"
linked2 = linkage(df[['BloodPressure', 'Age']], 'average')

plt.figure(figsize=(10, 7))
dendrogram(linked2,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BloodPressure и Age')
plt.show()

# %% [markdown]
# ## centroid

# %%
# Для "BMI, Age"
linked1 = linkage(df[['BMI', 'Age']], 'centroid')

plt.figure(figsize=(10, 7))
dendrogram(linked1,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BMI и Age')
plt.show()

# Для "BloodPressure, Age"
linked2 = linkage(df[['BloodPressure', 'Age']], 'centroid')

plt.figure(figsize=(10, 7))
dendrogram(linked2,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BloodPressure и Age')
plt.show()

# %% [markdown]
# ## ward

# %%
# Для "BMI, Age"
linked1 = linkage(df[['BMI', 'Age']], 'ward')

plt.figure(figsize=(10, 7))
dendrogram(linked1,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BMI и Age')
plt.show()

# Для "BloodPressure, Age"
linked2 = linkage(df[['BloodPressure', 'Age']], 'ward')

plt.figure(figsize=(10, 7))
dendrogram(linked2,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BloodPressure и Age')
plt.show()

# %% [markdown]
# # weighted

# %%
# Для "BMI, Age"
linked1 = linkage(df[['BMI', 'Age']], 'weighted')

plt.figure(figsize=(10, 7))
dendrogram(linked1,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BMI и Age')
plt.show()

# Для "BloodPressure, Age"
linked2 = linkage(df[['BloodPressure', 'Age']], 'weighted')

plt.figure(figsize=(10, 7))
dendrogram(linked2,
            orientation='top',
            labels=df.index.to_list(),
            distance_sort='descending',
            show_leaf_counts=True)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.title('Дендрограмма иерархической кластеризации для BloodPressure и Age')
plt.show()
